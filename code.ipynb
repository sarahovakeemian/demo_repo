# %%
print('hello world. New feature added.')

# %%
import time

for i in range(1, 15):
  time.sleep(10)
  x=i
  print (f'hello, printing {i}')

# %%
print('hi')

# %%
# print ('testing change')

# %%
# from serverless_gpu import distributed
# import serverless_gpu
# import time

# @distributed(
#   gpus=8,
#   gpu_type='H100',
#   remote=False)
# def hello_world(name: str):
#   print(f"Hello {name}, from Serverless GPU Compute!")
#   time.sleep (120)
#   print (f'after sleep')

# %%
# hello_world.distributed(name='Sara')

# %%
# !nvidia-smi

# %%
# from serverless_gpu import distributed

# @distributed(
#     gpus=1,
#     gpu_type='H100',
#     remote=False, 
# )
# def hello_world(name: str):
#     statement=f'hello {name}'
#     print(statement)
#     import time
#     time.sleep (120)
#     print(f'after sleep {statment}')
#     return statement

# %%
# name='Lin'

# %%
# hello_world.distributed(name)

# %%
# %sh nvidia-smi
